# %% [markdown]
# ## Atabey's Notes
#
# I like your exploratory data analysis, and your detailed list of questions. However, you have no methodology section. As such there is a disconnect between the questions you are asking and the data set you have. You have to be very specific about how you are going to answer the questions you are asking.
#
# 90/100

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Please don't run the import commands again, I only used them to show the headers of the files, imports will fail because I haven't uploaded the files to the repo.

# %%
appearances = pd.read_csv("appearances.csv")
club_games = pd.read_csv("club_games.csv")
clubs = pd.read_csv("clubs.csv")
competitions = pd.read_csv("competitions.csv")
game_events = pd.read_csv("game_events.csv")
game_lineups = pd.read_csv("game_lineups.csv")
games = pd.read_csv("games.csv")
player_valuations = pd.read_csv("player_valuations.csv")
players = pd.read_csv("players.csv")

# %%
pd.set_option('display.max_columns', 100)

# %% [markdown]
# [Properties of Data](#Properties-of-Data)
#     <ul>
#     <li>[Club Games](#Club-Games)</li>
#     <li>[Clubs](#Clubs)</li>
#     <li>[Competitions](#Competitions)</li>
#     <li>[Game Events](#Game-Events)</li>
#     <li>[Game Lineups](#Game-Lineups)</li>
#     <li>[Games](#Games)</li>
#     <li>[Player Valuations](#Player-Valuations)</li>
#     <li>[Players](#Players)</li>
#     </ul>
# [Questions](#Questions)

# %% [markdown]
# # Analys of Football Data from Transfermarkt

# %% [markdown]
# This data is a football data created by pulling data from [transfermarkt.com](https://www.transfermarkt.com.tr/) with the help of the script in the github repository [here](https://github.com/dcaribou/transfermarkt-datasets). And here is where i find the data: https://data.world/dcereijo/player-scores

# %% [markdown]
# ## Properties of Data

# %% [markdown]
# This data contains 9 different csv files. These files contain scores of matches played in various leagues in Europe between 2011 and 2023, the number of fans in these matches, the result of these matches, the number of goals contributed by the players in these matches, the number of minutes played by each player, the number of cards shown in these matches, the details and minutes of events in these matches, and the market value of these players.

# %% [markdown]
# ### Appearances

# %%
appearances.head()
# Out:
#     appearance_id  game_id  player_id  player_club_id  player_current_club_id  \
# 0   2231978_38004  2231978      38004             853                     235
# 1   2233748_79232  2233748      79232            8841                    2698
# 2   2234413_42792  2234413      42792            6251                     465
# 3   2234418_73333  2234418      73333            1274                    6646
# 4  2234421_122011  2234421     122011             195                    3008
#
#          date       player_name competition_id  yellow_cards  red_cards  \
# 0  2012-07-03  Aurélien Joachim            CLQ             0          0
# 1  2012-07-05    Ruslan Abyshov            ELQ             0          0
# 2  2012-07-05       Sander Puri            ELQ             0          0
# 3  2012-07-05   Vegar Hedenstad            ELQ             0          0
# 4  2012-07-05  Markus Henriksen            ELQ             0          0
#
#    goals  assists  minutes_played
# ...

# %% [markdown]
# #### The appearances file has 1502807 rows and 13 columns. Every row represent different players different match stats. <br>
# <b>appearance_id:</b> Unique identifier for each player appearance in a game.<br>
# <b>game_id:</b> Identifier for the game in which the player appeared.<br>
# <b>player_id:</b> Unique identifier for each player.<br>
# <b>player_club_id:</b> Identifier for the club to which the player belonged at the time of the appearance.<br>
# <b>player_current_club_id:</b> Identifier for the current club of the player (if applicable).<br>
# <b>date:</b> Date of the player's appearance in the game.<br>
# <b>player_name:</b> Name of the player.<br>
# <b>competition_id:</b> Identifier for the competition or league in which the game took place.<br>
# <b>yellow_cards:</b> Number of yellow cards received by the player in the game.<br>
# <b>red_cards:</b> Number of red cards received by the player in the game.<br>
# <b>goals:</b> Number of goals scored by the player in the game.<br>
# <b>assists:</b> Number of assists made by the player in the game.<br>
# <b>minutes_played:</b> Total minutes played by the player in the game.<br>

# %% [markdown]
# ### Club Games

# %%
club_games.head()
# Out:
#    game_id  club_id  own_goals  own_position      own_manager_name  \
# 0  2221751      431          1           NaN         Lutz Göttling
# 1  2221755       83          3           NaN      Ralph Hasenhüttl
# 2  2222597     3725          2           2.0  Stanislav Cherchesov
# 3  2222627     2696          0          11.0        Andrey Kobelev
# 4  2222658     2410          0           2.0        Leonid Slutski
#
#    opponent_id  opponent_goals  opponent_position opponent_manager_name  \
# 0           60               2                NaN     Christian Streich
# 1         4795               0                NaN            Tomas Oral
# 2          232               1                5.0            Unai Emery
# 3         4128               2               10.0         Rustem Khuzin
# 4          121               2               13.0          Dan Petrescu
#
#   hosting  is_win
# 0    Home       0
# 1    Home       1
# 2    Home       1
# 3    Home       0
# 4    Home       0

# %% [markdown]
# #### The appearances file has 130080 rows and 11 columnss. Every row represent different clubs different match stats.
#
# <b>game_id:</b> Unique identifier for each game.<br>
# <b>club_id:</b> Identifier for the club participating in the game.<br>
# <b>own_goals:</b> Number of goals scored by the club.<br>
# <b>own_position:</b> Position of the club in the league or tournament.<br>
# <b>own_manager_name:</b> Name of the manager of the club.<br>
# <b>opponent_id:</b> Identifier for the opposing club in the game.<br>
# <b>opponent_goals:</b> Number of goals scored by the opposing club.<br>
# <b>opponent_position:</b> Position of the opposing club in the league or tournament.<br>
# <b>opponent_manager_name:</b> Name of the manager of the opposing club.<br>
# <b>hosting:</b> Indicates whether the club is hosting the game.<br>
# <b>is_win:</b> Indicates whether the club won the game (binary: 1 for win, 0 for loss or draw).<br>

# %% [markdown]
# ### Clubs

# %%
clubs.head()
# Out:
#    club_id          club_code                              name  \
# 0      105    sv-darmstadt-98  Sportverein Darmstadt 1898 e. V.
# 1    11127  ural-ekaterinburg             FK Ural Yekaterinburg
# 2      114  besiktas-istanbul         Beşiktaş Jimnastik Kulübü
# 3       12             as-rom        Associazione Sportiva Roma
# 4      148  tottenham-hotspur   Tottenham Hotspur Football Club
#
#   domestic_competition_id  total_market_value  squad_size  average_age  \
# 0                      L1                 NaN          30         26.4
# 1                     RU1                 NaN          25         28.2
# 2                     TR1                 NaN          32         27.4
# 3                     IT1                 NaN          26         27.3
# 4                     GB1                 NaN          29         26.1
#
#    foreigners_number  foreigners_percentage  national_team_players  \
# 0                 11                   36.7                      1
# ...

# %% [markdown]
# #### The clubs file has 426 rows and 16 columns. Every row represent a club and every column indicates a property of a that club.
#
# <b>club_id:</b> Unique identifier for each club. <br>
# <b>club_code:</b> Code or abbreviation associated with the club.<br>
# <b>name:</b> Name of the club.<br>
# <b>domestic_competition_id:</b> Identifier for the domestic competition or league in which the club participates.<br>
# <b>total_market_value:</b> Total market value of the club's squad.<br>
# <b>squad_size:</b> Number of players in the club's squad.<br>
# <b>average_age:</b> Average age of the players in the club's squad.<br>
# <b>foreigners_number:</b> Number of foreign players in the squad.<br>
# <b>foreigners_percentage:</b> Percentage of foreign players in the squad.<br>
# <b>national_team_players:</b> Number of players in the squad who are also part of their national teams.<br>
# <b>stadium_name:</b> Name of the club's stadium.<br>
# <b>stadium_seats:</b> Number of seats in the club's stadium.<br>
# <b>net_transfer_record:</b> Net transfer spending record for the club.<br>
# <b>coach_name:</b> Name of the coach or manager of the club.<br>
# <b>last_season:</b> Information about the club's performance in the last season.<br>
# <b>url:</b> URL or web link associated with the club for additional information.<br>

# %% [markdown]
# ### Competitions

# %%
competitions.head()
# Out:
#   competition_id               competition_code  \
# 0            CIT                      italy-cup
# 1           NLSC           johan-cruijff-schaal
# 2            GRP                kypello-elladas
# 3           POSU  supertaca-candido-de-oliveira
# 4           RUSS              russian-super-cup
#
#                             name            sub_type          type  \
# 0                      italy-cup        domestic_cup  domestic_cup
# 1           johan-cruijff-schaal  domestic_super_cup         other
# 2                kypello-elladas        domestic_cup  domestic_cup
# 3  supertaca-candido-de-oliveira  domestic_super_cup         other
# 4              russian-super-cup  domestic_super_cup         other
#
#    country_id country_name domestic_league_code confederation  \
# 0          75        Italy                  IT1        europa
# 1         122  Netherlands                  NL1        europa
# 2          56       Greece                  GR1        europa
# ...

# %% [markdown]
# #### The competitions file has 42 rows and 10 columns. Every row represent a competition and every column indicates a property of a that competition.
#
# <b>competition_id:</b> Unique identifier for each competition.<br>
# <b>competition_code:</b> Code or abbreviation associated with the competition.<br>
# <b>name:</b> Name of the competition.<br>
# <b>sub_type:</b> Subtype or category of the competition.<br>
# <b>type:</b> Type or nature of the competition.<br>
# <b>country_id:</b> Unique identifier for the country associated with the competition.<br>
# <b>country_name:</b> Name of the country associated with the competition.<br>
# <b>domestic_league_code:</b> Code or abbreviation associated with the domestic league related to the competition.<br>
# <b>confederation:</b> Confederation or governing body overseeing the competition.<br>
# <b>url:</b> URL or web link associated with the competition for additional information.<br>

# %% [markdown]
# ### Game Events

# %%
game_events.head()
# Out:
#                       game_event_id        date  game_id  minute  \
# 0  2f41da30c471492e7d4a984951671677  2012-08-05  2211607      77
# 1  a72f7186d132775f234d3e2f7bc0ed5b  2012-08-05  2211607      77
# 2  b2d721eaed4692a5c59a92323689ef18  2012-08-05  2211607       3
# 3  aef768899cedac0c9a650980219075a2  2012-08-05  2211607      53
# 4  5d6d9533023057b6619ecd145a038bbe  2012-08-05  2211607      74
#
#             type  club_id  player_id  \
# 0          Cards      610       4425
# 1          Cards      383      33210
# 2          Goals      383      36500
# 3          Goals      383      36500
# 4  Substitutions      383      36500
#
#                                          description  player_in_id  \
# 0               1. Yellow card  , Mass confrontation           NaN
# 1               1. Yellow card  , Mass confrontation           NaN
# 2  , Header, 1. Tournament Goal Assist: , Corner,...           NaN
# 3  , Right-footed shot, 2. Tournament Goal Assist...           NaN
# ...

# %% [markdown]
# #### The game_events file has 663843 rows and 10 columns. Every row represent an event in the game and every column indicates a detail of that event.
#
# <b>game_event_id:</b> Unique identifier for each game event.<br>
# <b>date:</b> Date when the game event occurred.<br>
# <b>game_id:</b> Identifier for the game in which the event took place.<br>
# <b>minute:</b> The minute of the game in which the event occurred.<br>
# <b>type:</b> Type of the game event (e.g., goal, substitution, card).<br>
# <b>club_id:</b> Identifier for the club associated with the event.<br>
# <b>player_id:</b> Identifier for the player involved in the event.<br>
# <b>description:</b> A description or details about the game event.<br>
# <b>player_in_id:</b> Identifier for the player who entered the game (relevant for substitution events).<br>
# <b>player_assist_id:</b> Identifier for the player who provided an assist in the event (relevant for events like goals).<br>

# %% [markdown]
# ### Game Lineups

# %%
game_lineups.head()
# Out:
#                     game_lineups_id  game_id  club_id             type number  \
# 0  baa0d6827dab4fab07d8dc1604e720a7  3606208      338  starting_lineup     15
# 1  77b0f371923e0c8bdf050a1e269faaac  3606208      338  starting_lineup     89
# 2  8e63d5f47aac2bdb0e54f5481986e104  3606208      338  starting_lineup      5
# 3  cb6eeedb9f728570615d37b6fe7facaf  3606208      338  starting_lineup     10
# 4  3b0a25b9c76eedd7f6faaec061abf671  3606208      338  starting_lineup     29
#
#    player_id         player_name  team_captain            position
# 0     264372    Viktor Tsygankov             0        Right Winger
# 1     419061  Vladyslav Supryaga             0      Centre-Forward
# 2     124182    Sergiy Sydorchuk             1  Defensive Midfield
# 3     368611   Mykola Shaparenko             0    Central Midfield
# 4     167722   Vitaliy Buyalskyi             0  Attacking Midfield

# %% [markdown]
# #### The game_lineups file has 111666 rows and 9 columns. Every row lineup for a game and every column indicates a detail of that lineup.
#
# <b>game_lineups_id:</b> Unique identifier for each game lineup.<br>
# <b>game_id:</b> Identifier for the game associated with the lineup.<br>
# <b>club_id:</b> Identifier for the club whose lineup is being recorded.<br>
# <b>type:</b> Type of lineup (e.g., starting lineup, substitution).<br>
# <b>number:</b> Jersey number of the player in the lineup.<br>
# <b>player_id:</b> Unique identifier for the player.<br>
# <b>player_name:</b> Name of the player in the lineup.<br>
# <b>team_captain:</b> Indicates whether the player is the team captain (binary: 1 for captain, 0 for not captain).<br>
# <b>position:</b> Position of the player in the lineup (e.g., forward, midfielder, defender).<br>

# %% [markdown]
# ### Games

# %%
games.head()
# Out:
#    game_id competition_id  season         round        date  home_club_id  \
# 0  2222597            RU1    2012   6. Matchday  2012-08-25          3725
# 1  2222627            RU1    2012   5. Matchday  2012-08-20          2696
# 2  2222658            RU1    2012  10. Matchday  2012-09-30          2410
# 3  2222664            RU1    2012   8. Matchday  2012-09-15           932
# 4  2222683            RU1    2012  12. Matchday  2012-10-22          2696
#
#    away_club_id  home_club_goals  away_club_goals  home_club_position  \
# 0           232                2                1                 2.0
# 1          4128                0                2                11.0
# 2           121                0                2                 2.0
# 3          2698                1                0                 5.0
# 4         12438                0                1                11.0
#
#    away_club_position home_club_manager_name away_club_manager_name  \
# ...

# %% [markdown]
# #### The games file has 65040 rows and 23 columns. Every row represent a game and every column indicates a detail of that game.
#
# <b>game_id:</b> Unique identifier for each game.<br>
# <b>competition_id:</b> Identifier for the competition or league in which the game is played.<br>
# <b>season:</b> Season during which the game is played.<br>
# <b>round:</b> Round or stage of the competition to which the game belongs.<br>
# <b>date:</b> Date of the game.<br>
# <b>home_club_id:</b> Identifier for the home club.<br>
# <b>away_club_id:</b> Identifier for the away club.<br>
# <b>home_club_goals:</b> Number of goals scored by the home club in the game.<br>
# <b>away_club_goals:</b> Number of goals scored by the away club in the game.<br>
# <b>home_club_position:</b> Position of the home club in the league or tournament.<br>
# <b>away_club_position:</b> Position of the away club in the league or tournament.<br>
# <b>home_club_manager_name:</b> Name of the manager of the home club.<br>
# <b>away_club_manager_name:</b> Name of the manager of the away club.<br>
# <b>stadium:</b> Name of the stadium where the game is played.<br>
# <b>attendance:</b> Number of spectators or attendees at the game.<br>
# <b>referee:</b> Name of the referee officiating the game.<br>
# <b>url:</b> URL or web link associated with the game for additional information.<br>
# <b>home_club_formation:</b> Formation used by the home club in the game.<br>
# <b>away_club_formation:</b> Formation used by the away club in the game.<br>
# <b>home_club_name:</b> Name of the home club.<br>
# <b>away_club_name:</b> Name of the away club.<br>
# <b>aggregate:</b> Indicates whether the game is part of an aggregate score (e.g., in two-legged ties).<br>
# <b>competition_type:</b> Type or nature of the competition (e.g., league, cup).<br>

# %% [markdown]
# ### Player Valuations

# %%
player_valuations.head()
# Out:
#    player_id  last_season             datetime        date    dateweek  \
# 0       3132         2013  2003-12-09 00:00:00  2003-12-09  2003-12-08
# 1       6893         2012  2003-12-15 00:00:00  2003-12-15  2003-12-15
# 2         10         2015  2004-10-04 00:00:00  2004-10-04  2004-10-04
# 3         26         2017  2004-10-04 00:00:00  2004-10-04  2004-10-04
# 4         65         2015  2004-10-04 00:00:00  2004-10-04  2004-10-04
#
#    market_value_in_eur  n  current_club_id player_club_domestic_competition_id
# 0               400000  1              126                                 TR1
# 1               900000  1              984                                 GB1
# 2              7000000  1              398                                 IT1
# 3              1500000  1               16                                  L1
# 4              8000000  1             1091                                 GR1

# %% [markdown]
# #### The player_valuations file has 440663 rows and 9 columns. Every row represent a players valuation in a spesific time.
#
# <b>player_id:</b> Unique identifier for each player.<br>
# <b>last_season:</b> Season in which the player's data is recorded.<br>
# <b>datetime:</b> Date and time of the recorded data.<br>
# <b>date:</b> Date associated with the recorded data.<br>
# <b>dateweek:</b> Week number corresponding to the date.<br>
# <b>market_value_in_eur:</b> Market value of the player in euros.<br>
# <b>current_club_id:</b> Identifier for the player's current club.<br>
# <b>player_club_domestic_competition_id:</b> Identifier for the domestic competition or league in which the player's current club participates.<br>

# %% [markdown]
# ### Players

# %%
players.head()
# Out:
#    player_id first_name   last_name              name  last_season  \
# 0        598       Timo  Hildebrand   Timo Hildebrand         2014
# 1        670     Martin      Petrov     Martin Petrov         2012
# 2       1323     Martin     Amedick    Martin Amedick         2012
# 3       3195   Jermaine     Pennant  Jermaine Pennant         2013
# 4       3259     Damien        Duff       Damien Duff         2013
#
#    current_club_id       player_code country_of_birth city_of_birth  \
# 0               24   timo-hildebrand          Germany         Worms
# 1              714     martin-petrov         Bulgaria        Vratsa
# 2               24    martin-amedick          Germany     Paderborn
# 3              512  jermaine-pennant          England    Nottingham
# 4              931       damien-duff          Ireland    Ballyboden
#
#   country_of_citizenship date_of_birth    sub_position    position   foot  \
# 0                Germany    1979-04-05      Goalkeeper  Goalkeeper    NaN
# ...

# %% [markdown]
# #### The players file has 30302 rows and 23 columns. Every row represent a player and every column indicates a property of that player.
#
# <b>player_id:</b> Unique identifier for each player.<br>
# <b>first_name:</b> First name of the player.<br>
# <b>last_name:</b> Last name of the player.<br>
# <b>name:</b> Full name of the player.<br>
# <b>last_season:</b> Season in which the player's data is recorded.<br>
# <b>current_club_id:</b> Identifier for the player's current club.<br>
# <b>player_code:</b> Code or identifier associated with the player.<br>
# <b>country_of_birth:</b> Country in which the player was born.<br>
# <b>city_of_birth:</b> City in which the player was born.<br>
# <b>country_of_citizenship:</b> Country of citizenship of the player.<br>
# <b>date_of_birth:</b> Date of birth of the player.<br>
# <b>sub_position:</b> Sub-position or specific role within a position (if applicable).<br>
# <b>position:</b> General playing position of the player.<br>
# <b>foot:</b> Dominant foot of the player (e.g., left, right).<br>
# <b>height_in_cm:</b> Height of the player in centimeters.<br>
# <b>market_value_in_eur:</b> Current market value of the player in euros.<br>
# <b>highest_market_value_in_eur:</b> Highest market value ever attained by the player in euros.<br>
# <b>contract_expiration_date:</b> Date when the player's current contract with their club is set to expire.<br>
# <b>agent_name:</b> Name of the player's agent or representative.<br>
# <b>image_url:</b> URL of an image representing the player.<br>
# <b>url:</b> URL or web link associated with the player for additional information.<br>
# <b>current_club_domestic_competition_id:</b> Identifier for the domestic competition or league in which the player's current club participates.<br>
# <b>current_club_name:</b> Name of the player's current club.<br>

# %% [markdown]
# ## Questions

# %% [markdown]
# <b>[1](#Question-1)</b> Who are the top 10 goal scorers since 2012?<br>
# <b>[2](#Question-2)</b> Which players have recorded the most assists since 2012?<br>
# <b>[3](#Question-3)</b> Who are the top 10 goal scorers per minute played since 2012?<br>
# <b>[4](#Question-4)</b> In which playing positions do players most frequently contribute assists?<br>
# <b>[5](#Question-5)</b> Who are the top 10 players with the most cards since 2012?<br>
# <b>[6](#Question-6)</b> In which playing positions do players most frequently receive yellow cards?<br>
# <b>[7](#Question-7)</b> In which playing positions do players most frequently receive red cards?<br>
# <b>[8](#Question-8)</b>  What changes have occurred in the number of spectators in football matches over the years?<br>
# <b>[9](#Question-9)</b> Which are the top 10 teams for both scoring and conceding goals since 2012?<br>
# <b>[10](#Question-10)</b> Which are the top 10 teams for both winning and losing matches since 2012?<br>
# <b>[11](#Question-11)</b> Is there a correlation between being a home or away team and match victories?<br>
# <b>[12](#Question-12)</b> Which teams are the most and least successful in converting opportunities into goals?<br>
# <b>[13](#Question-13)</b> As of 2023, which are the top 10 teams with the highest squad values?<br>
# <b>[14](#Question-14)</b> As of 2023, which teams have the highest and lowest average squad ages?<br>
# <b>[15](#Question-15)</b> As of 2023, which are the top 10 teams with the highest stadium capacities?<br>
# <b>[16](#Question-16)</b> What is the average squad value for teams in each league?<br>
# <b>[17](#Question-17)</b> What is the average squad size for teams in each league?<br>
# <b>[18](#Question-18)</b> What is the average stadium capacity for teams in each league?<br>
# <b>[19](#Question-19)</b> Which league produces the most national team players?<br>
# <b>[20](#Question-20)</b> What is the relationship between the percentage of foreign players in a team and its squad value?<br>
# <b>[21](#Question-21)</b> What is the relationship between the average age of teams and their squad values?<br>
# <b>[22](#Question-22)</b> Which are the top 10 matches with the most cards since 2012?<br>
# <b>[23](#Question-23)</b> Which are the top 10 highest-scoring matches since 2012?<br>
# <b>[24](#Question-24)</b> Who are the top 10 winningest coaches since 2012?<br>
# <b>[25](#Question-25)</b> How does the stadium occupancy rate relate to the home team's victory?<br>
# <b>[26](#Question-26)</b> Are there referees causing notable variations in teams' average performances?<br>
# <b>[27](#Question-27)</b> Which are the top 10 teams with the highest and lowest win ratios based on the ratio of scoring a goal to creating a opporunity?<br>
# <b>[28](#Question-28)</b> What are the highest market values for players each year?<br>
# <b>[29](#Question-29)</b> As of 2023, what is the average market value for players based on their positions?<br>
# <b>[30](#Question-30)</b> Who are the players that have experienced the greatest increase in market value within a year, and by how much has their value increased?<br>
# <b>[31](#Question-31)</b> What is the impact of goals and assists by attacking players on their market values?<br>
# <b>[32](#Question-32)</b> What is the relationship between players' ages and their market values?<br>
# <b>[33](#Question-33)</b> Is there a correlation between players' heights and their market values?<br>
# <b>[34](#Question-34)</b> Is there a relationship between the preferred foot of attacking players and the number of goals or assists they contribute?<br>
# <b>[35](#Question-35)</b> Who are the top 10 referees in terms of officiating the most matches since 2012?<br>
# <b>[36](#Question-36)</b> Which referees have shown the most cards in matches since 2012?<br>
# <b>[37](#Question-37)</b> Who are the top 10 players in terms of total playing time in matches since 2012?<br>
# <b>[38](#Question-38)</b> Since 2012, who are the top 10 players with the most victories and the most defeats?<br>
# <b>[39](#Question-39)</b> How has the number of goals scored in a season varied across different leagues over the years?<br>

# %% [markdown]
# #### Question 1
#
# For this question I will use the appearances file. I will group the player_id value with the groupby function in the Appearances file and sum the goals values with the sum function. Then I will sort by values and find the 10 highest values.

# %% [markdown]
# #### Question 2
#
# For this question I will use the appearances file. I will group the player_id value with the groupby function and sum the assist values with the sum function. Then I will sort by values and find the 10 highest values.

# %% [markdown]
# #### Question 3
#
# For this question I will use the appearances file. I will group the player_id value with the groupby function and sum the goals and minutes_played values with the sum function. I will divide minutes_played by goals to find out how many goals a player scores every minute on average. Then I will sort these values and show the 10 highest ones.

# %% [markdown]
# #### Question 4
#
# For this question I will use the appearances and players file. I will get the positions of the players and merge them with appearances file. Then i will group the players position with the groupby function and sum the assist values with the sum function.

# %% [markdown]
# #### Question 5
#
# For this question I will use the appearances file. I will group the player with player_id then i will sum the yellow_cards and red_cards. After that i will sort the values and show the top 10 values.

# %% [markdown]
# #### Question 6
#
# For this question I will use the appearances and players file. I will get the positions of the players and merge them with appearances file. Then i will group the players position with the groupby function and sum the yellow values with the sum function.

# %% [markdown]
# #### Question 7
#
# For this question I will use the appearances and players file. I will get the positions of the players and merge them with appearances file. Then i will group the players position with the groupby function and sum the red values with the sum function.

# %% [markdown]
# #### Question 8
#
# I will use the games file for this question. I will group the matches by years with the groupby function and aggregate the attendance value with the mean function and then display the attendance rate over the years.

# %% [markdown]
# #### Question 9
# For this question i will use the the club_games file. I will group the teams by team_id value with groupby function and i will sum the goals that team scored and conceded then i will sort values with these parameters separately. Then i will show the 10 top most values.

# %% [markdown]
# #### Question 10
# For this question i will use the the club_games file. I will group the teams by team_id value with groupby function and i will sum the in_win values. Then i will show the top 10 values.

# %% [markdown]
# #### Question 11
# For this question i will use the club_games file.

# %% [markdown]
# #### Question 12
# For this question i will use club_games file. I will group the teams by team_id value with groupby function and i will divide the number of goals to number of positions. Then i will sort the teams by this ratio and show the most succesful and unsuccesfull 10 teams.

# %% [markdown]
# #### Question 13
# For this question i will use clubs file. I will sort the teams by total market value and i will show the 10 most valuable teams.

# %% [markdown]
# #### Question 14
# For this question i will use clubs file. I will sort the teams by average_age value and i will show the 10 most old and young teams.

# %% [markdown]
# #### Question 15
#
# For this question i will use clubs file. I will sort the teams by stadium_seats value and i will show the 10 biggest capacity.

# %% [markdown]
# #### Question 16
# For this question i will use clubs file. I will group the teams by their leauge with groupby function and aggregate total market value with sum function and divide this value to number of teams. Then i will sort values by average market values of leauges and show the top 10 leauges.

# %% [markdown]
# #### Question 17
# For this question i will use clubs file. I will group the teams by their leauge with groupby function and aggregate squad size value with sum function and divide this value to number of teams. Then i will sort values by average squat size values of leauges and show the top 10 teams.

# %% [markdown]
# #### Question 18
# For this question i will use clubs file. I will group the teams by their leauge with groupby function and aggregate stadium seats value with sum function and divide this value to number of teams. Then i will sort values by average stadium seat values of leauges and show the top 10 teams.

# %% [markdown]
# #### Question 19
#
# For this question i will use clubs file.

# %% [markdown]
# #### Question 20
#
# For this question i will use clubs file. I will measure the corelation between percentage of foreign players in a team and its squad value with using pearson correlation coefficent and spearman rank correlation coefficent.

# %% [markdown]
# #### Question 21
#
# For this question i will use clubs file. I will measure the corelation between average age of teams and their squad values in a team and its squad value with using pearson correlation coefficent and spearman rank correlation coefficent.

# %% [markdown]
# #### Question 22
#
# For this question i will use the game_events file. I will group the matches by their id with groupby function and aggregate card number with sum. Then i will sort values and show top 10 matches.

# %% [markdown]
# #### Question 23
#
# For this question i will use the games file. I will sum the home_teams_goals and away_teams_goals then i will sort matches and i will show the top 10 matches.

# %% [markdown]
# #### Question 24
#
# For this questin i will use the club games file. I will group the games by manager name and i will aggregate the is_winning value with sum function. Then i will sort values and show top 10.

# %% [markdown]
# #### Question 25
#
# For this question i will use clubs and games file. First of all i will measure the winning ratio of each team then i will find the attendence percentage for each match and i will use polynominal regression to find relationship between attendence and result of match

# %% [markdown]
# #### Question 26
#
# For this question I will use the games file. First I will calculate the average wins of the teams, then I will analyze the win rates of these teams according to the referees who officiated the matches and try to find out if there is a referee who is out of the average.

# %% [markdown]
# #### Question 27
#
# For this question I will use the club games file. First of all, I will analyze the teams' goal scoring rates, then I will compare these rates with the teams' win rates and find the 10 teams with the highest and the 10 teams with the lowest win rates according to their goal scoring rates.

# %% [markdown]
# #### Question 28
#
# For this question I will use the player valuations file. First of all I will group the rows by years using the groupby function, then I will aggregate them with the max function and find the highest valued players by year.

# %% [markdown]
# #### Question 29
#
# For this question, I will use the player valuations file. First of all, I will extract only the data for the year 2023 from the file, then I will group and analyze the data according to the players' positions.

# %% [markdown]
# #### Question 30
#
# For this question I will use the player valuations file. I will compare the market value of each player with the previous year's market value and plot the values of the players with the highest increase in value.

# %% [markdown]
# #### Question 31
#
# For this question I will use the player valuations and game events file. I will find the number of goals scored and assists made by each offensive player during the period of change in market value and try to analyze the relationship between them with polynomial regression.

# %% [markdown]
# #### Question 32
#
# For this question I will use the player valuations file. I will group the players by age with the groupby function, find their average market value and then try to calculate the relationship between age and market value with polynomial regression.

# %% [markdown]
# #### Question 33
#
# For this question I will use the player valuations file file. I will group players by height and display the correlation between height and market value.

# %% [markdown]
# #### Question 34
#
# For this question, I will use the player valuations file, and I will display a correlation between the market value and which foot the players who are career equals use. As a career equivalent I will consider goal scoring and win rates.

# %% [markdown]
# #### Question 35
#
# For this question I will use the games file. I will group the matches by referees and show the referees who officiated the most matches.

# %% [markdown]
# #### Question 36
#
# For this question I will use the games and game events file. With the games file I will find the referees who officiated the match and from the game events file I will find the number of cards shown in that match and then list the referees who showed the most cards.

# %% [markdown]
# #### Question 37
#
# For this question I will use the appearances file. I will group the footballers according to their ids and sum them according to minutes played value and then list the footballers with the most minutes played.

# %% [markdown]
# #### Question 38
#
# For this question I will use the appearances and games file. From the appearances file I will find the matches played by each footballer and from the games file I will find the results of these matches and then I will list the teams with the most wins and most defeats.

# %% [markdown]
# #### Question 39
# For this question I will use the games file. I will group the matches by leagues, separate them by dates, then find the average number of goals scored in each season and compare the leagues with each other and with each other.

# %% [markdown]
# I will do this on my Asus Evo VivoBook S435EA-KC031T i5-1135G7 8 GB 256 GB 14" W10H FHD personal computer. I will carry out the work alone.
